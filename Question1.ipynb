# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('cybersecurity_attacks.csv')

# %%
data
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# 1            17245             48166     ICMP           1174        Data
# 2            16811             53600      UDP            306     Control
# 3            20018             32534      UDP            385        Data
# 4             6131             26646      TCP           1462        Data
# ...            ...               ...      ...            ...         ...
# 39995        31005              6764      UDP           1428     Control
# 39996         2553             28091      UDP           1184     Control
# 39997        22505             25152      UDP           1043        Data
# 39998        20013              2703      UDP            483        Data
# 39999        50137             55575     ICMP           1175     Control
#
#       Traffic Type                                       Payload Data  ...  \
# 0             HTTP  Qui natus odio asperiores nam. Optio nobis ius...  ...
# 1             HTTP  Aperiam quos modi officiis veritatis rem. Omni...  ...
# 2             HTTP  Perferendis sapiente vitae soluta. Hic delectu...  ...
# 3             HTTP  Totam maxime beatae expedita explicabo porro l...  ...
# 4              DNS  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...
# ...            ...                                                ...  ...
# 39995         HTTP  Quibusdam ullam consequatur consequuntur accus...  ...
# 39996         HTTP  Quaerat neque esse. Animi expedita natus commo...  ...
# 39997          DNS  Enim at aspernatur illum. Saepe numquam eligen...  ...
# 39998          FTP  Officiis dolorem sed harum provident earum dis...  ...
# 39999         HTTP  Eligendi omnis voluptate nihil voluptatibus do...  ...
#
#       Action Taken  Severity Level User Information  \
# 0           Logged             Low    Reyansh Dugal
# 1          Blocked             Low       Sumer Rana
# 2          Ignored             Low     Himmat Karpe
# 3          Blocked          Medium       Fateh Kibe
# 4          Blocked             Low     Dhanush Chad
# ...            ...             ...              ...
# 39995       Logged          Medium      Adira Madan
# 39996       Logged            High        Rati Dara
# 39997      Blocked             Low     Samiha Joshi
# 39998      Ignored             Low    Rasha Chauhan
# 39999       Logged          Medium      Zaina Kumar
#
#                                       Device Information Network Segment  \
# 0      Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1      Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3      Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4      Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
# ...                                                  ...             ...
# 39995  Mozilla/5.0 (iPad; CPU iPad OS 14_2_1 like Mac...       Segment A
# 39996  Mozilla/5.0 (Windows; U; Windows 98; Win 9x 4....       Segment C
# 39997  Mozilla/5.0 (Windows; U; Windows NT 4.0) Apple...       Segment C
# 39998  Mozilla/5.0 (X11; Linux i686) AppleWebKit/536....       Segment B
# 39999  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment A
#
#                    Geo-location Data Proxy Information Firewall Logs  \
# 0                 Jamshedpur, Sikkim      150.9.97.135      Log Data
# 1                 Bilaspur, Nagaland               NaN      Log Data
# 2                  Bokaro, Rajasthan    114.133.48.179      Log Data
# 3                 Jaunpur, Rajasthan               NaN           NaN
# 4                 Anantapur, Tripura     149.6.110.119           NaN
# ...                              ...               ...           ...
# 39995                Nashik, Manipur               NaN      Log Data
# 39996              Vadodara, Mizoram       60.51.30.46      Log Data
# 39997  Mahbubnagar, Himachal Pradesh               NaN      Log Data
# 39998    Rourkela, Arunachal Pradesh      137.76.130.8      Log Data
# 39999       Pudukkottai, West Bengal   112.169.115.139      Log Data
#
#       IDS/IPS Alerts Log Source
# 0                NaN     Server
# 1                NaN   Firewall
# 2         Alert Data   Firewall
# 3         Alert Data   Firewall
# 4         Alert Data   Firewall
# ...              ...        ...
# 39995     Alert Data   Firewall
# 39996            NaN   Firewall
# 39997     Alert Data     Server
# 39998            NaN     Server
# 39999     Alert Data   Firewall
#
# [40000 rows x 25 columns]

# %%
data.shape
# Out:
# (40000, 25)

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (1237, 25)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1237, 25)

# %%
data.isnull().sum()
# Out:
# Timestamp                 0
# Source IP Address         0
# Destination IP Address    0
# Source Port               0
# Destination Port          0
# Protocol                  0
# Packet Length             0
# Packet Type               0
# Traffic Type              0
# Payload Data              0
# Malware Indicators        0
# Anomaly Scores            0
# Alerts/Warnings           0
# Attack Type               0
# Attack Signature          0
# Action Taken              0
# Severity Level            0
# User Information          0
# Device Information        0
# Network Segment           0
# Geo-location Data         0
# Proxy Information         0
# Firewall Logs             0
# IDS/IPS Alerts            0
# Log Source                0
# dtype: int64

# %%
data.iloc[0,0]
# Out:
# '2022-11-13 08:23:25'

# %%
data.iloc[[3,4]]
# Out:
#                Timestamp Source IP Address Destination IP Address  \
# 97   2021-10-25 04:23:15   129.189.216.143         197.202.27.160
# 105  2022-10-30 05:51:47      62.75.113.77         216.196.28.158
#
#      Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 97         19199             27928     ICMP           1178        Data
# 105        42864             48696     ICMP            765     Control
#
#     Traffic Type                                       Payload Data  ...  \
# 97          HTTP  Eaque deserunt nemo ad voluptate. Aliquid rem ...  ...
# 105          DNS  Dolores vitae neque velit maiores.\nReprehende...  ...
#
#     Action Taken  Severity Level User Information  \
# 97       Ignored            High      Ira Kapadia
# 105      Blocked             Low      Arnav Krish
#
#                                     Device Information Network Segment  \
# 97   Mozilla/5.0 (compatible; MSIE 8.0; Windows 95;...       Segment C
# 105  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment C
#
#         Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts  \
# 97   Tirunelveli, Gujarat    57.192.174.154      Log Data     Alert Data
# 105        Ranchi, Sikkim     199.194.2.180      Log Data     Alert Data
#
#     Log Source
# 97      Server
# 105     Server
#
# [2 rows x 25 columns]

# %%
x=data.iloc[:,:-1]

# %%
x
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 7      2023-02-12 07:13:17      11.48.99.245         178.157.14.116
# 46     2023-05-16 13:01:56    170.211.138.30         172.97.181.148
# 97     2021-10-25 04:23:15   129.189.216.143         197.202.27.160
# 105    2022-10-30 05:51:47      62.75.113.77         216.196.28.158
# ...                    ...               ...                    ...
# 39832  2023-01-15 00:16:35    192.68.130.174           47.59.96.194
# 39887  2022-01-31 14:01:44     185.115.82.22           184.58.72.27
# 39896  2020-09-23 07:09:09     85.96.253.113         78.219.210.210
# 39905  2020-12-30 20:32:48       91.16.73.36          172.76.179.79
# 39956  2022-06-17 02:41:11     205.9.232.102             57.3.168.6
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 2            16811             53600      UDP            306     Control
# 7            34489             20396     ICMP           1022        Data
# 46           25022              6593      TCP            554     Control
# 97           19199             27928     ICMP           1178        Data
# 105          42864             48696     ICMP            765     Control
# ...            ...               ...      ...            ...         ...
# 39832        34978             62423     ICMP           1003        Data
# 39887         7461             13910      TCP            361        Data
# 39896        22124             61792      UDP            665        Data
# 39905        26461              2781     ICMP            143        Data
# 39956         8642             32255      TCP            714     Control
#
#       Traffic Type                                       Payload Data  ...  \
# 2             HTTP  Perferendis sapiente vitae soluta. Hic delectu...  ...
# 7              DNS  Amet libero optio quidem praesentium libero. E...  ...
# 46             DNS  Voluptate mollitia cupiditate necessitatibus n...  ...
# 97            HTTP  Eaque deserunt nemo ad voluptate. Aliquid rem ...  ...
# 105            DNS  Dolores vitae neque velit maiores.\nReprehende...  ...
# ...            ...                                                ...  ...
# 39832         HTTP  Explicabo illo aut voluptas voluptates invento...  ...
# 39887          DNS  Illo facilis voluptate eveniet inventore. Labo...  ...
# 39896          DNS  Atque minus molestiae quam soluta nobis verita...  ...
# 39905         HTTP  Labore blanditiis reiciendis ad architecto exp...  ...
# 39956         HTTP  Quam provident enim nostrum. Officia ea cupidi...  ...
#
#       Attack Signature  Action Taken Severity Level User Information  \
# 2      Known Pattern B       Ignored            Low     Himmat Karpe
# 7      Known Pattern A        Logged           High     Yuvaan Dubey
# 46     Known Pattern B       Blocked           High   Aradhya Kamdar
# 97     Known Pattern B       Ignored           High      Ira Kapadia
# 105    Known Pattern A       Blocked            Low      Arnav Krish
# ...                ...           ...            ...              ...
# 39832  Known Pattern B        Logged            Low    Indranil Sood
# 39887  Known Pattern B       Ignored           High   Advik Majumdar
# 39896  Known Pattern B       Blocked         Medium       Kiara Dara
# 39905  Known Pattern B        Logged           High  Anya Srivastava
# 39956  Known Pattern A        Logged           High    Zeeshan Karan
#
#                                       Device Information Network Segment  \
# 2      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 7      Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_6...       Segment A
# 46     Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...       Segment A
# 97     Mozilla/5.0 (compatible; MSIE 8.0; Windows 95;...       Segment C
# 105    Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment C
# ...                                                  ...             ...
# 39832  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/531.1...       Segment B
# 39887  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...       Segment C
# 39896  Mozilla/5.0 (iPad; CPU iPad OS 9_3_5 like Mac ...       Segment A
# 39905  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1 ...       Segment B
# 39956  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...       Segment A
#
#               Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts
# 2             Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 7      Phagwara, Andhra Pradesh      192.31.159.5      Log Data     Alert Data
# 46             Amravati, Kerala     95.170.137.42      Log Data     Alert Data
# 97         Tirunelveli, Gujarat    57.192.174.154      Log Data     Alert Data
# 105              Ranchi, Sikkim     199.194.2.180      Log Data     Alert Data
# ...                         ...               ...           ...            ...
# 39832                 Kota, Goa    139.77.228.178      Log Data     Alert Data
# 39887     Kishanganj, Karnataka    148.235.69.173      Log Data     Alert Data
# 39896       Durgapur, Meghalaya   188.237.180.226      Log Data     Alert Data
# 39905     Sikar, Madhya Pradesh     223.20.78.165      Log Data     Alert Data
# 39956           Maheshtala, Goa     43.57.174.231      Log Data     Alert Data
#
# [1237 rows x 24 columns]

# %%
y=data.iloc[:,6]

# %%
y
# Out:
# 2         306
# 7        1022
# 46        554
# 97       1178
# 105       765
#          ...
# 39832    1003
# 39887     361
# 39896     665
# 39905     143
# 39956     714
# Name: Packet Length, Length: 1237, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y=LabelEncoder().fit_transform(y)

# %%
y=pd.DataFrame(y)

# %%
y.head()
# Out:
#      0
# 0  135
# 1  547
# 2  287
# 3  630
# 4  397

# %%
numeric_features=x.select_dtypes('number')

# %%
categorical_features=x.select_dtypes('object')

# %%
categorical_features
# Out:
#                  Timestamp Source IP Address Destination IP Address Protocol  \
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17      UDP
# 7      2023-02-12 07:13:17      11.48.99.245         178.157.14.116     ICMP
# 46     2023-05-16 13:01:56    170.211.138.30         172.97.181.148      TCP
# 97     2021-10-25 04:23:15   129.189.216.143         197.202.27.160     ICMP
# 105    2022-10-30 05:51:47      62.75.113.77         216.196.28.158     ICMP
# ...                    ...               ...                    ...      ...
# 39832  2023-01-15 00:16:35    192.68.130.174           47.59.96.194     ICMP
# 39887  2022-01-31 14:01:44     185.115.82.22           184.58.72.27      TCP
# 39896  2020-09-23 07:09:09     85.96.253.113         78.219.210.210      UDP
# 39905  2020-12-30 20:32:48       91.16.73.36          172.76.179.79     ICMP
# 39956  2022-06-17 02:41:11     205.9.232.102             57.3.168.6      TCP
#
#       Packet Type Traffic Type  \
# 2         Control         HTTP
# 7            Data          DNS
# 46        Control          DNS
# 97           Data         HTTP
# 105       Control          DNS
# ...           ...          ...
# 39832        Data         HTTP
# 39887        Data          DNS
# 39896        Data          DNS
# 39905        Data         HTTP
# 39956     Control         HTTP
#
#                                             Payload Data Malware Indicators  \
# 2      Perferendis sapiente vitae soluta. Hic delectu...       IoC Detected
# 7      Amet libero optio quidem praesentium libero. E...       IoC Detected
# 46     Voluptate mollitia cupiditate necessitatibus n...       IoC Detected
# 97     Eaque deserunt nemo ad voluptate. Aliquid rem ...       IoC Detected
# 105    Dolores vitae neque velit maiores.\nReprehende...       IoC Detected
# ...                                                  ...                ...
# 39832  Explicabo illo aut voluptas voluptates invento...       IoC Detected
# 39887  Illo facilis voluptate eveniet inventore. Labo...       IoC Detected
# 39896  Atque minus molestiae quam soluta nobis verita...       IoC Detected
# 39905  Labore blanditiis reiciendis ad architecto exp...       IoC Detected
# 39956  Quam provident enim nostrum. Officia ea cupidi...       IoC Detected
#
#        Alerts/Warnings Attack Type Attack Signature Action Taken  \
# 2      Alert Triggered        DDoS  Known Pattern B      Ignored
# 7      Alert Triggered   Intrusion  Known Pattern A       Logged
# 46     Alert Triggered     Malware  Known Pattern B      Blocked
# 97     Alert Triggered     Malware  Known Pattern B      Ignored
# 105    Alert Triggered   Intrusion  Known Pattern A      Blocked
# ...                ...         ...              ...          ...
# 39832  Alert Triggered   Intrusion  Known Pattern B       Logged
# 39887  Alert Triggered     Malware  Known Pattern B      Ignored
# 39896  Alert Triggered     Malware  Known Pattern B      Blocked
# 39905  Alert Triggered        DDoS  Known Pattern B       Logged
# 39956  Alert Triggered     Malware  Known Pattern A       Logged
#
#       Severity Level User Information  \
# 2                Low     Himmat Karpe
# 7               High     Yuvaan Dubey
# 46              High   Aradhya Kamdar
# 97              High      Ira Kapadia
# 105              Low      Arnav Krish
# ...              ...              ...
# 39832            Low    Indranil Sood
# 39887           High   Advik Majumdar
# 39896         Medium       Kiara Dara
# 39905           High  Anya Srivastava
# 39956           High    Zeeshan Karan
#
#                                       Device Information Network Segment  \
# 2      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 7      Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_6...       Segment A
# 46     Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...       Segment A
# 97     Mozilla/5.0 (compatible; MSIE 8.0; Windows 95;...       Segment C
# 105    Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment C
# ...                                                  ...             ...
# 39832  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/531.1...       Segment B
# 39887  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...       Segment C
# 39896  Mozilla/5.0 (iPad; CPU iPad OS 9_3_5 like Mac ...       Segment A
# 39905  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1 ...       Segment B
# 39956  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...       Segment A
#
#               Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts
# 2             Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 7      Phagwara, Andhra Pradesh      192.31.159.5      Log Data     Alert Data
# 46             Amravati, Kerala     95.170.137.42      Log Data     Alert Data
# 97         Tirunelveli, Gujarat    57.192.174.154      Log Data     Alert Data
# 105              Ranchi, Sikkim     199.194.2.180      Log Data     Alert Data
# ...                         ...               ...           ...            ...
# 39832                 Kota, Goa    139.77.228.178      Log Data     Alert Data
# 39887     Kishanganj, Karnataka    148.235.69.173      Log Data     Alert Data
# 39896       Durgapur, Meghalaya   188.237.180.226      Log Data     Alert Data
# 39905     Sikar, Madhya Pradesh     223.20.78.165      Log Data     Alert Data
# 39956           Maheshtala, Goa     43.57.174.231      Log Data     Alert Data
#
# [1237 rows x 20 columns]

# %%
numeric_features
# Out:
#        Source Port  Destination Port  Packet Length  Anomaly Scores
# 2            16811             53600            306           87.42
# 7            34489             20396           1022           54.05
# 46           25022              6593            554           97.82
# 97           19199             27928           1178            5.39
# 105          42864             48696            765           47.31
# ...            ...               ...            ...             ...
# 39832        34978             62423           1003           48.15
# 39887         7461             13910            361           76.20
# 39896        22124             61792            665           95.85
# 39905        26461              2781            143           12.12
# 39956         8642             32255            714            9.74
#
# [1237 rows x 4 columns]

# %%
y.head
# Out:
# <bound method NDFrame.head of         0
# 0     135
# 1     547
# 2     287
# 3     630
# 4     397
# ...   ...
# 1232  538
# 1233  167
# 1234  348
# 1235   43
# 1236  374
#
# [1237 rows x 1 columns]>

# %%
data.shape
# Out:
# (1237, 25)

# %%
x.head
# Out:
# <bound method NDFrame.head of                  Timestamp Source IP Address Destination IP Address  \
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 7      2023-02-12 07:13:17      11.48.99.245         178.157.14.116
# 46     2023-05-16 13:01:56    170.211.138.30         172.97.181.148
# 97     2021-10-25 04:23:15   129.189.216.143         197.202.27.160
# 105    2022-10-30 05:51:47      62.75.113.77         216.196.28.158
# ...                    ...               ...                    ...
# 39832  2023-01-15 00:16:35    192.68.130.174           47.59.96.194
# 39887  2022-01-31 14:01:44     185.115.82.22           184.58.72.27
# 39896  2020-09-23 07:09:09     85.96.253.113         78.219.210.210
# 39905  2020-12-30 20:32:48       91.16.73.36          172.76.179.79
# 39956  2022-06-17 02:41:11     205.9.232.102             57.3.168.6
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 2            16811             53600      UDP            306     Control
# 7            34489             20396     ICMP           1022        Data
# 46           25022              6593      TCP            554     Control
# 97           19199             27928     ICMP           1178        Data
# 105          42864             48696     ICMP            765     Control
# ...            ...               ...      ...            ...         ...
# 39832        34978             62423     ICMP           1003        Data
# 39887         7461             13910      TCP            361        Data
# 39896        22124             61792      UDP            665        Data
# 39905        26461              2781     ICMP            143        Data
# 39956         8642             32255      TCP            714     Control
#
#       Traffic Type                                       Payload Data  ...  \
# 2             HTTP  Perferendis sapiente vitae soluta. Hic delectu...  ...
# 7              DNS  Amet libero optio quidem praesentium libero. E...  ...
# 46             DNS  Voluptate mollitia cupiditate necessitatibus n...  ...
# 97            HTTP  Eaque deserunt nemo ad voluptate. Aliquid rem ...  ...
# 105            DNS  Dolores vitae neque velit maiores.\nReprehende...  ...
# ...            ...                                                ...  ...
# 39832         HTTP  Explicabo illo aut voluptas voluptates invento...  ...
# 39887          DNS  Illo facilis voluptate eveniet inventore. Labo...  ...
# 39896          DNS  Atque minus molestiae quam soluta nobis verita...  ...
# 39905         HTTP  Labore blanditiis reiciendis ad architecto exp...  ...
# 39956         HTTP  Quam provident enim nostrum. Officia ea cupidi...  ...
#
#       Attack Signature  Action Taken Severity Level User Information  \
# 2      Known Pattern B       Ignored            Low     Himmat Karpe
# 7      Known Pattern A        Logged           High     Yuvaan Dubey
# 46     Known Pattern B       Blocked           High   Aradhya Kamdar
# 97     Known Pattern B       Ignored           High      Ira Kapadia
# 105    Known Pattern A       Blocked            Low      Arnav Krish
# ...                ...           ...            ...              ...
# 39832  Known Pattern B        Logged            Low    Indranil Sood
# 39887  Known Pattern B       Ignored           High   Advik Majumdar
# 39896  Known Pattern B       Blocked         Medium       Kiara Dara
# 39905  Known Pattern B        Logged           High  Anya Srivastava
# 39956  Known Pattern A        Logged           High    Zeeshan Karan
#
#                                       Device Information Network Segment  \
# 2      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 7      Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_6...       Segment A
# 46     Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...       Segment A
# 97     Mozilla/5.0 (compatible; MSIE 8.0; Windows 95;...       Segment C
# 105    Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment C
# ...                                                  ...             ...
# 39832  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/531.1...       Segment B
# 39887  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...       Segment C
# 39896  Mozilla/5.0 (iPad; CPU iPad OS 9_3_5 like Mac ...       Segment A
# 39905  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1 ...       Segment B
# 39956  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...       Segment A
#
#               Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts
# 2             Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 7      Phagwara, Andhra Pradesh      192.31.159.5      Log Data     Alert Data
# 46             Amravati, Kerala     95.170.137.42      Log Data     Alert Data
# 97         Tirunelveli, Gujarat    57.192.174.154      Log Data     Alert Data
# 105              Ranchi, Sikkim     199.194.2.180      Log Data     Alert Data
# ...                         ...               ...           ...            ...
# 39832                 Kota, Goa    139.77.228.178      Log Data     Alert Data
# 39887     Kishanganj, Karnataka    148.235.69.173      Log Data     Alert Data
# 39896       Durgapur, Meghalaya   188.237.180.226      Log Data     Alert Data
# 39905     Sikar, Madhya Pradesh     223.20.78.165      Log Data     Alert Data
# 39956           Maheshtala, Goa     43.57.174.231      Log Data     Alert Data
#
# [1237 rows x 24 columns]>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 12151  2021-12-04 21:26:53     122.187.37.42         137.162.23.167
# 17023  2023-08-30 02:23:18      64.18.116.38           47.26.195.39
# 14163  2022-07-04 21:33:38    148.137.115.82          44.14.246.201
# 11589  2022-02-15 16:11:05     51.97.151.105         213.171.188.29
# 18299  2020-06-29 12:52:53   213.179.156.189         138.66.137.126
# ...                    ...               ...                    ...
# 33587  2020-10-16 16:56:17      95.79.50.186            35.46.3.188
# 35286  2022-12-03 04:55:39    197.252.209.50         132.232.56.200
# 36242  2021-06-26 08:05:18      88.53.212.13         177.178.56.123
# 27439  2020-08-04 17:56:54    132.116.90.118          60.70.149.126
# 36188  2023-09-25 17:06:44    128.243.31.212           28.93.166.86
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 12151        61869             16673     ICMP           1364        Data
# 17023        24475             13775      TCP            463     Control
# 14163        15170             33617      UDP            472        Data
# 11589        15419              1519     ICMP            475     Control
# 18299        43532             57567      UDP            839        Data
# ...            ...               ...      ...            ...         ...
# 33587        24160             39481      UDP           1014        Data
# 35286        28028             32362      UDP           1283        Data
# 36242        13013             16606      UDP            537        Data
# 27439        24477             17070     ICMP            112     Control
# 36188        32666             60326      UDP           1485        Data
#
#       Traffic Type                                       Payload Data  ...  \
# 12151          FTP  Esse nesciunt odio nobis. Animi in iste asperi...  ...
# 17023         HTTP  Magnam voluptate veniam. Mollitia culpa saepe ...  ...
# 14163         HTTP  Deserunt possimus error ipsam quod. Praesentiu...  ...
# 11589          FTP  Asperiores repellendus ullam. Deserunt volupta...  ...
# 18299          DNS  Blanditiis eligendi excepturi dolore sed sit v...  ...
# ...            ...                                                ...  ...
# 33587         HTTP  Accusantium a animi fugit velit.\nMinus ad bea...  ...
# 35286          FTP  Ad distinctio hic. Pariatur animi fuga neque.\...  ...
# 36242         HTTP  Delectus perferendis ipsum inventore unde odit...  ...
# 27439          FTP  Deserunt hic cum numquam nobis. Deserunt quam ...  ...
# 36188          FTP  Ratione aperiam laudantium optio. Expedita acc...  ...
#
#       Attack Signature  Action Taken Severity Level  User Information  \
# 12151  Known Pattern B        Logged           High       Lavanya Sha
# 17023  Known Pattern A       Ignored           High        Divit Sama
# 14163  Known Pattern B       Ignored         Medium  Chirag Varughese
# 11589  Known Pattern B       Blocked            Low      Ishita Barad
# 18299  Known Pattern B       Blocked         Medium    Darshit Biswas
# ...                ...           ...            ...               ...
# 33587  Known Pattern B        Logged         Medium   Shayak Bhargava
# 35286  Known Pattern B       Blocked            Low      Samarth Dora
# 36242  Known Pattern A       Blocked            Low      Reyansh Bala
# 27439  Known Pattern A        Logged            Low     Ojas Sundaram
# 36188  Known Pattern A       Ignored           High       Chirag Gola
#
#                                       Device Information Network Segment  \
# 12151  Mozilla/5.0 (iPhone; CPU iPhone OS 14_2_1 like...       Segment C
# 17023  Mozilla/5.0 (compatible; MSIE 7.0; Windows CE;...       Segment B
# 14163  Mozilla/5.0 (Windows; U; Windows NT 5.2) Apple...       Segment C
# 11589  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...       Segment B
# 18299  Mozilla/5.0 (iPad; CPU iPad OS 9_3_5 like Mac ...       Segment A
# ...                                                  ...             ...
# 33587  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_10_9 r...       Segment A
# 35286  Mozilla/5.0 (Windows NT 6.2; sd-IN; rv:1.9.1.2...       Segment A
# 36242  Opera/9.37.(Windows NT 4.0; gez-ET) Presto/2.9...       Segment B
# 27439  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_5...       Segment A
# 36188  Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...       Segment A
#
#            Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts
# 12151         Rajkot, Odisha     217.44.181.42      Log Data     Alert Data
# 17023    Vijayawada, Manipur        84.0.5.169      Log Data     Alert Data
# 14163       Saharsa, Gujarat     51.159.80.157      Log Data     Alert Data
# 11589        Nagaon, Haryana     27.41.212.229      Log Data     Alert Data
# 18299  Kochi, Madhya Pradesh    20.227.124.133      Log Data     Alert Data
# ...                      ...               ...           ...            ...
# 33587    Patna, Chhattisgarh     96.149.54.163      Log Data     Alert Data
# 35286          Imphal, Assam       80.7.206.38      Log Data     Alert Data
# 36242    Akola, Chhattisgarh    181.215.31.166      Log Data     Alert Data
# 27439        Bhopal, Manipur     189.165.21.90      Log Data     Alert Data
# 36188        Motihari, Bihar     209.26.149.66      Log Data     Alert Data
#
# [989 rows x 24 columns]

# %%
x_test
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 19927  2022-01-16 00:42:00    207.116.67.102        210.164.213.245
# 5866   2021-06-05 13:45:14     222.1.199.150         93.253.166.232
# 27722  2021-11-27 16:20:31     68.231.58.235         223.70.145.216
# 30369  2020-02-24 01:21:08    24.203.143.137         189.231.25.117
# 31452  2021-05-04 17:59:47     83.80.253.252        218.210.234.179
# ...                    ...               ...                    ...
# 28150  2023-09-09 09:12:14    59.245.197.168         194.72.233.108
# 5998   2023-05-18 11:30:43    38.124.108.150            102.86.8.82
# 1079   2023-02-16 19:55:40    161.33.136.148          175.52.151.40
# 27999  2022-11-24 17:08:33     57.113.27.132          131.165.87.11
# 32145  2020-07-05 16:48:17       136.97.0.78         102.46.255.155
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 19927        33582             30969     ICMP            833     Control
# 5866          7272             50287      TCP            130        Data
# 27722        36397              1873      TCP            648     Control
# 30369         7659             24663      TCP            321        Data
# 31452        51355             51715      TCP            156        Data
# ...            ...               ...      ...            ...         ...
# 28150        54363             54669     ICMP            691        Data
# 5998         44765             31091      UDP           1118        Data
# 1079         50709             12081     ICMP            941        Data
# 27999         8497             24184      TCP            621     Control
# 32145        26605             64063     ICMP            700        Data
#
#       Traffic Type                                       Payload Data  ...  \
# 19927          DNS  Culpa unde laboriosam expedita harum officiis ...  ...
# 5866          HTTP  Nam non harum inventore necessitatibus odio fu...  ...
# 27722          DNS  Atque harum non maxime fugit quisquam. Nobis a...  ...
# 30369          DNS  Velit necessitatibus minima molestias incidunt...  ...
# 31452          DNS  Quos natus perferendis laudantium ipsa. Debiti...  ...
# ...            ...                                                ...  ...
# 28150          FTP  Repudiandae voluptates facilis possimus maiore...  ...
# 5998           DNS  Eos dolor quam ea ipsum. Voluptatem natus earu...  ...
# 1079          HTTP  In ducimus impedit possimus. Dolores accusamus...  ...
# 27999          FTP  Nostrum sit debitis et ad corporis nulla. Vero...  ...
# 32145          DNS  Laborum totam ipsam. Sed recusandae quaerat of...  ...
#
#       Attack Signature  Action Taken Severity Level User Information  \
# 19927  Known Pattern A        Logged           High   Ritvik Mallick
# 5866   Known Pattern A       Ignored           High        Zoya Anne
# 27722  Known Pattern B       Blocked            Low    Darshit Atwal
# 30369  Known Pattern A       Blocked           High      Shamik Gade
# 31452  Known Pattern A        Logged           High     Inaaya  Mani
# ...                ...           ...            ...              ...
# 28150  Known Pattern A       Blocked            Low    Emir Sankaran
# 5998   Known Pattern B       Blocked         Medium         Ojas Rau
# 1079   Known Pattern B       Blocked            Low       Lagan Mani
# 27999  Known Pattern A       Ignored           High      Chirag Mane
# 32145  Known Pattern A       Blocked         Medium     Dhruv Khatri
#
#                                       Device Information Network Segment  \
# 19927  Opera/8.25.(X11; Linux i686; ca-ES) Presto/2.9...       Segment B
# 5866   Mozilla/5.0 (Linux; Android 2.3.4) AppleWebKit...       Segment C
# 27722  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_3 like...       Segment B
# 30369  Mozilla/5.0 (Android 4.1.2; Mobile; rv:51.0) G...       Segment B
# 31452  Mozilla/5.0 (Windows; U; Windows NT 5.2) Apple...       Segment B
# ...                                                  ...             ...
# 28150  Mozilla/5.0 (Linux; Android 7.1.1) AppleWebKit...       Segment A
# 5998   Mozilla/5.0 (Windows 95; wa-BE; rv:1.9.0.20) G...       Segment B
# 1079   Mozilla/5.0 (compatible; MSIE 6.0; Windows 98;...       Segment C
# 27999  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....       Segment A
# 32145  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_1 like M...       Segment A
#
#                              Geo-location Data Proxy Information  \
# 19927                           Hajipur, Bihar     41.139.25.175
# 5866   Raurkela Industrial Township, Karnataka     67.232.224.42
# 27722                     Lucknow, Uttarakhand      92.12.78.180
# 30369                        Singrauli, Kerala       84.9.62.125
# 31452                 Pudukkottai, Maharashtra     40.114.67.117
# ...                                        ...               ...
# 28150                           Jodhpur, Assam    106.128.65.156
# 5998                        Ghaziabad, Mizoram    153.44.131.143
# 1079                          Ramgarh, Gujarat   190.101.148.194
# 27999                      Mirzapur, Meghalaya      128.4.160.65
# 32145                        Ghaziabad, Odisha     157.35.96.120
#
#       Firewall Logs IDS/IPS Alerts
# 19927      Log Data     Alert Data
# 5866       Log Data     Alert Data
# 27722      Log Data     Alert Data
# 30369      Log Data     Alert Data
# 31452      Log Data     Alert Data
# ...             ...            ...
# 28150      Log Data     Alert Data
# 5998       Log Data     Alert Data
# 1079       Log Data     Alert Data
# 27999      Log Data     Alert Data
# 32145      Log Data     Alert Data
#
# [248 rows x 24 columns]

# %%
y_train
# Out:
#         0
# 365   740
# 526   222
# 430   229
# 350   230
# 566   441
# ...   ...
# 1044  545
# 1095  689
# 1130  274
# 860    27
# 1126  818
#
# [989 rows x 1 columns]

# %%
y_test
# Out:
#         0
# 614   438
# 174    35
# 869   339
# 941   144
# 980    50
# ...   ...
# 876   362
# 178   600
# 31    499
# 873   326
# 1004  367
#
# [248 rows x 1 columns]
